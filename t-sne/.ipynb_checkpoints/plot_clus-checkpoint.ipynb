# %%
import pandas as pd

from matplotlib import pyplot as plt
from matplotlib.pyplot import figure

# %%
df_tsne = pd.read_csv('C:/Users/enterprise/Google Drive/fake_news_resources/raw_data/tsne_200.csv')

# %%
df_tsne.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.079363  0.056652  0.131635  0.181985 -0.077590  0.163969  0.268569
# 1  0.187514 -0.117532  0.212321  0.169369 -0.068645  0.104395  0.196029
# 2  0.063562  0.099867  0.105196  0.008667 -0.120491 -0.043890  0.248002
# 3  0.036314  0.108824  0.067064  0.141104 -0.043921  0.111751  0.279939
# 4  0.124340 -0.062889  0.128010  0.175044 -0.061351  0.096961  0.193578
#
#           7         8         9    ...          193       194       195  \
# 0  0.096867  0.146928  0.132340    ...    -0.159278  0.119939 -0.167914
# 1  0.181140  0.429525 -0.028684    ...     0.204344  0.054274  0.066674
# 2  0.053538  0.252559  0.160082    ...    -0.151694  0.109905 -0.339849
# 3  0.103269  0.112140  0.143998    ...    -0.234239  0.174508 -0.199214
# 4  0.174761  0.272709  0.017073    ...     0.074645  0.063666  0.006912
#
#         196       197       198       199  class     x-tsne    y-tsne
# 0  0.345973  0.027744 -0.221527  0.060562      0 -11.792394  2.580707
# 1  0.172758 -0.030026 -0.151404  0.055431      0 -39.776615 -5.331606
# 2  0.238901 -0.079800 -0.228725  0.138899      0  -9.315325  8.252152
# 3  0.374246  0.053308 -0.271306  0.116270      0 -11.736360  2.674987
# 4  0.136749  0.043222 -0.164594  0.051087      0 -37.565968 -6.805406
#
# [5 rows x 203 columns]

# %%
plt.scatter(df_tsne['x-tsne'], df_tsne['y-tsne'], c=df_tsne['class'], cmap=plt.cm.get_cmap("jet", 10))
#plt.colorbar(ticks=range(10))
#plt.clim(-0.5, 9.5)

index = df_tsne.index.tolist()

for i in index:
    plt.annotate(i, xy=(df_tsne['x-tsne'][i], df_tsne['y-tsne'][i]))

plt.xlim(-50, -30)
plt.ylim(-10, 10)
plt.show()

# %%
cs_news = []
cg_news = []

for i, row in df_tsne.iterrows():
    if (-50 < row['x-tsne'] < -30) and (-10 < row['y-tsne'] < 10):
        cs_news.append(i)
    else:
        cg_news.append(i)

# %%
print(len(cs_news))
print(len(cg_news))
# Out:
# 179
# 1309

# %%
news = pd.read_json('C:/Users/enterprise/Google Drive/fake_news_resources/raw_data/cross_title.json')

# %%
cs_fil = news.iloc[cs_news]
cg_fil = news.iloc[cg_news]

# %%
print(cs_fil[['text', 'title', 'class']].head())
# Out:
#                                                 text  \
# 1  Las manteconchas no fueron creadas рor Bimbo, ...
# 4  En las imágenes, se puede apreciar al can de c...
# 5  En YouTube circula un video que ráрidamente se...
# 8  Un рequeño beisbolista es el рrotagonista en l...
# 9  Este niño imрactó en Facebook al demostrar que...
#
#                                                title  class
# 1  ahora bimbo pretende robarse las manteconchas ...      0
# 4  hermoso perrito roba una camara gopro se graba...      0
# 5  la emotiva reaccion perro al ver dueno despues...      0
# 8  nino recibe la indicacion correr lo mas rapido...      0
# 9  pequeno ayuda papa lavar los platos e impacta ...      0

# %%
print(cg_fil[['text', 'title', 'class']].head())
# Out:
#                                                 text  \
# 0  En Facebооk pоdemоs encоntrar diversоs videоs,...
# 2  Redes.- Captan el mоmentо en que un accidente ...
# 3  La creatividad de estоs niñоs impactó a tоdоs....
# 6  Cuandо esta hermоsa ave mueve su cabeza de lad...
# 7  Gracias a Facebооk, una de las redes sоciales ...
#
#                                                title  class
# 0  adorable cacatua canta una cancion bebe causa ...      0
# 2  aterrador video nina queda moto marcha tras ca...      0
# 3   estos ninos te robaran corazon banda rock lindos      0
# 6  mira la belleza magia del plumaje del colibri ...      0
# 7  nina dos anos vencio al cancer bailo feliz pad...      0
